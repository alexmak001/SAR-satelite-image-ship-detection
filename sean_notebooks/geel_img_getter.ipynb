# %%
import ee

# %%
import geemap
from datetime import datetime
import numpy as np
import rasterio
import matplotlib.pyplot as plt 
import pandas as pd
from datetime import date
from datetime import timedelta
import os

# %%
ee.Authenticate()

ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=QuvYe8Ed6yywi_ftd_BjH99Wj5yhmv4t125_PXCYa3E&tc=CFIXgi_t5yawyfMT8Dcy-PMTGTAuVlAJSl4o_NhM9Gk&cc=M5JSWaY_Xc8cag3GA3SI9yz8HLb4jNiyL3jbXx0Idrw>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=QuvYe8Ed6yywi_ftd_BjH99Wj5yhmv4t125_PXCYa3E&tc=CFIXgi_t5yawyfMT8Dcy-PMTGTAuVlAJSl4o_NhM9Gk&cc=M5JSWaY_Xc8cag3GA3SI9yz8HLb4jNiyL3jbXx0Idrw</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1ARtbsJqqPsS1y5Gy5SmMbFC9K4Gw9_6H4ZUT0EqMe4PmsDWlv80-D9Ho9nE
#
# Successfully saved authorization token.

# %%
def cloudscore(image):
    '''
    Inner function for computing cloud score such that we can remove 
    bad images from the landsat collections we download.
    Implementation in javascript can be found of Google Earth Engine 
    website under (landsat algorithms), translation to python by KH.
    Further help from Nicholas Clinton at 
    https://urldefense.com/v3/__https://gis.stackexchange.com/questions/252685/filter-landsat-images-base-on-cloud-cover-over-a-region-of-interest*5Cn__;JQ!!LLK065n_VXAQ!zP9K-68-_oPkaNWFZdbTYYnai85ggL4j3FhdqssLkim-RneBr2NqD6Ka4fu6yw-v$         '''
    cloud = ee.Algorithms.Landsat.simpleCloudScore(image).select('cloud')
    cloudiness = cloud.reduceRegion(ee.Reducer.mean(),
                                    geometry=region,
                                    scale=30)
    image = image.set(cloudiness)
    return image

# %%
# bounding box
bbox = [(115.85349259091208,38.89554742554994)
,(115.99408325863669,38.89554742554994)
,(115.99408325863669,38.966054593190535)
,(115.85349259091208,38.966054593190535)]

# %%
bands = ['B1','B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','QA_RADSAT','SAA','SZA','VAA','VZA']

# %%
start_date = datetime(2013,3,18)

end_date = datetime(2022,2,3)

region = ee.Geometry.Polygon(bbox)

collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA').filterDate(start_date,end_date).filterBounds(region)

cloud_tol=100
collection= collection.map(algorithm=cloudscore).filter(ee.Filter.lt('cloud', cloud_tol))

# %%
bad_dates = ['2013-04-05',
'2013-06-13',
 '2013-06-29',
 '2013-07-31',
 '2013-09-17',
 '2013-10-19',
 '2013-12-06',
 '2014-01-07',
 '2014-02-08',
 '2014-03-12',
 '2014-05-31',
 '2014-06-16',
 '2014-08-03',
 '2014-11-07',
 '2014-12-09',
 '2015-01-26',
 '2015-06-19',
 '2015-07-21',
 '2015-09-23',
 '2016-03-17',
 '2016-04-02',
 '2016-07-07',
 '2016-07-23',
 '2016-08-08',
 '2016-09-09',
 '2016-09-25',
 '2017-02-16',
 '2017-03-20',
 '2017-06-24',
 '2017-08-11',
 '2017-09-12',
 '2017-10-14',
 '2018-01-18',
 '2018-02-19',
 '2018-05-10',
 '2018-07-29',
 '2018-09-15',
 '2018-10-17',
 '2018-12-20',
 '2019-02-22',
 '2019-04-11',
 '2019-07-16',
 '2019-10-20',
 '2020-02-09',
 '2020-05-15',
 '2020-07-02',
 '2021-01-26',
 '2021-04-16',
 '2021-08-06',
 '2021-08-22',
 '2021-09-07',
 '2021-09-23',
 '2021-10-25']

from datetime import date

list_set = []
for i in range(len(bad_dates)):   
    datetime_object = date.fromisoformat(bad_dates[i])
    start = datetime_object + timedelta(days=1)
    end = datetime_object - timedelta(days=1)
    
    list_set.append((str(start), str(end)))

for i in range(len(list_set)):
    collection = collection.filter(ee.Filter.date(list_set[i][0], list_set[i][1]).Not())

# %%
collection = collection.select(bands)
collection_list = collection.toList(collection.size())

collection_size = collection_list.size().getInfo()
dates = geemap.image_dates(collection, date_format='YYYY-MM-dd').getInfo()

# %%
for i, date in enumerate(dates[:]):
    
    if date in bad_dates:
        continue
        
    image = ee.Image(collection_list.get(i))


    new_image = image.select(bands)

    geemap.ee_export_image(new_image, filename = "test_{}.tif".format(date), scale = 100, region = region, file_per_band = False)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/05e041796d139d0c5e61d5ceb30ced9a-8d28663f6874743006f1bb56d1e4c7c9:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-04-26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7a5a5674c739da1603a47bb256160cf4-a555a78dc7ece064b4bee37de969761b:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-05-12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/16841bb547a8d402bc31e80576cab44a-4158b062a39038b5253a727a94652978:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-08-16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b567a7660d6460b8eee54bb1f6b115c6-667e51dc90edd7d10da3756291bc5360:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-09-01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dc93cf3684845b045aa2dcf6ac749bfc-bfb3bf45fcd059a087a2672e49b31664:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-10-03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc79d67b59af45733ceb5d87f93bf908-7871eeafdf85d0596bc70f4a4ac26392:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-11-04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/685e5ceb33751f1101d60741d9a3e867-6057f0ba10862770b2bc1b6eeb444d5b:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-11-20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/10e0ce297310440fbc43afd7dee53977-7015562091504c3225a406f8800de830:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2013-12-22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7191c881460aac33946c8108df03854c-67174598ed102f6d3c7d751a87f8f817:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-04-13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a8d1def2b7a1253acc2d989663f018d4-26719e0e0c2cee2883559519ea7c53fc:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-04-29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e95162c28a2d922f48ea0bfb96e7ef04-2cf4027f7e062d03628eca36982c56a2:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-05-15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/430bb61c52ca3f80362c7a8b48c0804b-b39733e980448c7651febc6b353283e6:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-07-18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a2aea59fdc5c395d627aec2a73f05be6-0a0da2e23bf93e9b4ff7d70e1e54f509:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-08-19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a8864df3a085dc73dbbf08f64aaddd23-8318d84f8398dc7efadb3e9fdbc9f5af:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-09-04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5fd5cc1ef487578cd1c6d8dba956d51c-81b0cf6746e66c8c81c1c53889c5630a:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-09-20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eb1edd94471edbdce9d8c2f56aa89745-6742126f5509a4ae3be05ffe3836de2b:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-10-06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0cafad0a52ea0beaa5f4934d8aefeb29-acb19e90c81c5e6cc9d333dd16bb1d4c:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-10-22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ce7ba65621bf29dcfb96fbdfe689e89a-a72266e5dda2bc0b966e200265e8a020:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2014-12-25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3996ecbd78cd8f55cb1cfdf9046620a8-e66a8a8f8e78340e0613307fc565b1cb:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2015
getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2019-08-08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b138c136c71ddbe955bc0ed929ac7c2c-38977d18b8c520c68f653d3b0476ef71:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2019-08-24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/156af48c6d6fc6d58409fc0f9afe546e-c3329e465c86ed817b1e272142de6cf2:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2019-09-09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/941b1171b0125917fe4edc62f026b5b8-1cf04a4c8032861762fdef821bb00519:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2019-12-30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3d5ec0a633ac6880794b0897b6747ff9-c0e792c135d7518d70243b07dba5e1dc:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2020-07-25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/72f9d33501e259d587b697757c765b0d-65e9b60322af8fdb274e46e1bdff1268:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2020-08-10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1efa2cbaaaf4e9e96326d040197f08a7-6265dba3149d96d69fd62f47ed251729:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2020-08-26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9cef91d6ca79565de02af4c8c17dfca-f77b7afa26785a7e13257b18e89cc6a8:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2021-01-17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/409216cd14e22eb9cb34763ac7a57568-f8fa5759ed05c6f9c55f4433eda48cf0:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\test_2021-11-17.tif

# %%
import json

# %%
new_image

# %% [markdown]
# # get geisel

# %%
def cloudscore(image):
    '''
    Inner function for computing cloud score such that we can remove 
    bad images from the landsat collections we download.
    Implementation in javascript can be found of Google Earth Engine 
    website under (landsat algorithms), translation to python by KH.
    Further help from Nicholas Clinton at 
    https://urldefense.com/v3/__https://gis.stackexchange.com/questions/252685/filter-landsat-images-base-on-cloud-cover-over-a-region-of-interest*5Cn__;JQ!!LLK065n_VXAQ!zP9K-68-_oPkaNWFZdbTYYnai85ggL4j3FhdqssLkim-RneBr2NqD6Ka4fu6yw-v$         '''
    cloud = ee.Algorithms.Landsat.simpleCloudScore(image).select('cloud')
    cloudiness = cloud.reduceRegion(ee.Reducer.mean(),
                                    geometry=region,
                                    scale=30)
    image = image.set(cloudiness)
    return image

# %%
# bounding box
bbox = [(-117.26083311543401,32.84211213953877)
,(-117.17397245869573,32.84211213953877)
,(-117.17397245869573,32.92428198178219)
,(-117.26083311543401,32.92428198178219)]

# %%
bands = ['B1','B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','QA_RADSAT','SAA','SZA','VAA','VZA']

# %%
start_date = datetime(2022,1,1)

end_date = datetime(2022,2,1)

region = ee.Geometry.Polygon(bbox)

collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA').filterDate(start_date,end_date).filterBounds(region)

cloud_tol=100
collection= collection.map(algorithm=cloudscore).filter(ee.Filter.lt('cloud', cloud_tol))

# %%
bad_dates = ['2013-04-05',
'2013-06-13',
 '2013-06-29',
 '2013-07-31',
 '2013-09-17',
 '2013-10-19',
 '2013-12-06',
 '2014-01-07',
 '2014-02-08',
 '2014-03-12',
 '2014-05-31',
 '2014-06-16',
 '2014-08-03',
 '2014-11-07',
 '2014-12-09',
 '2015-01-26',
 '2015-06-19',
 '2015-07-21',
 '2015-09-23',
 '2016-03-17',
 '2016-04-02',
 '2016-07-07',
 '2016-07-23',
 '2016-08-08',
 '2016-09-09',
 '2016-09-25',
 '2017-02-16',
 '2017-03-20',
 '2017-06-24',
 '2017-08-11',
 '2017-09-12',
 '2017-10-14',
 '2018-01-18',
 '2018-02-19',
 '2018-05-10',
 '2018-07-29',
 '2018-09-15',
 '2018-10-17',
 '2018-12-20',
 '2019-02-22',
 '2019-04-11',
 '2019-07-16',
 '2019-10-20',
 '2020-02-09',
 '2020-05-15',
 '2020-07-02',
 '2021-01-26',
 '2021-04-16',
 '2021-08-06',
 '2021-08-22',
 '2021-09-07',
 '2021-09-23',
 '2021-10-25']

from datetime import date

list_set = []
for i in range(len(bad_dates)):   
    datetime_object = date.fromisoformat(bad_dates[i])
    start = datetime_object + timedelta(days=1)
    end = datetime_object - timedelta(days=1)
    
    list_set.append((str(start), str(end)))

for i in range(len(list_set)):
    collection = collection.filter(ee.Filter.date(list_set[i][0], list_set[i][1]).Not())

# %%
collection = collection.select(bands)
collection_list = collection.toList(collection.size())

collection_size = collection_list.size().getInfo()
dates = geemap.image_dates(collection, date_format='YYYY-MM-dd').getInfo()

# %%
for i, date in enumerate(dates[:]):
    
    if date in bad_dates:
        continue
        
    image = ee.Image(collection_list.get(i))


    new_image = image.select(bands)

    geemap.ee_export_image(new_image, filename = "geisel_test_3_{}.tif".format(date), scale = 100, region = region, file_per_band = False)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1ff1ce6cbc186978e9034891ee3b54d1-2287bf66923eb29837892b14fa20df47:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\geisel_test_3_2022-01-14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/802c695cff651c647b9bd11cf8a3975a-3a4c60fe72439c4b28d60fdcf0b5ee45:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\geisel_test_3_2022-01-30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a920cce94ce25be09c192ce4ac5dd68f-5858054b85f632bd40446b7401e90152:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\geisel_test_3_2022-01-14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e1409d10bab2caf24d336c52493cbe2b-a61e27a9b81ee710b47ca736dc8cfbf6:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\geisel_test_3_2022-01-30.tif

# %% [markdown]
# # Port of LA for Jan 2022

# %%
# bounding box
bbox = [(-118.32027994564326,33.64246038322455),
(-118.07789408138545,33.64246038322455),
(-118.07789408138545,33.78867573774964),
(-118.32027994564326,33.78867573774964),
(-118.32027994564326,33.64246038322455)]

# %%
bands = ['B1','B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','QA_RADSAT','SAA','SZA','VAA','VZA']

# %%
start_date = datetime(2022,1,1)

end_date = datetime(2022,2,1)

region = ee.Geometry.Polygon(bbox)

collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA').filterDate(start_date,end_date).filterBounds(region)

cloud_tol=100
collection= collection.map(algorithm=cloudscore).filter(ee.Filter.lt('cloud', cloud_tol))

# %%
bad_dates = ['2013-04-05',
'2013-06-13',
 '2013-06-29',
 '2013-07-31',
 '2013-09-17',
 '2013-10-19',
 '2013-12-06',
 '2014-01-07',
 '2014-02-08',
 '2014-03-12',
 '2014-05-31',
 '2014-06-16',
 '2014-08-03',
 '2014-11-07',
 '2014-12-09',
 '2015-01-26',
 '2015-06-19',
 '2015-07-21',
 '2015-09-23',
 '2016-03-17',
 '2016-04-02',
 '2016-07-07',
 '2016-07-23',
 '2016-08-08',
 '2016-09-09',
 '2016-09-25',
 '2017-02-16',
 '2017-03-20',
 '2017-06-24',
 '2017-08-11',
 '2017-09-12',
 '2017-10-14',
 '2018-01-18',
 '2018-02-19',
 '2018-05-10',
 '2018-07-29',
 '2018-09-15',
 '2018-10-17',
 '2018-12-20',
 '2019-02-22',
 '2019-04-11',
 '2019-07-16',
 '2019-10-20',
 '2020-02-09',
 '2020-05-15',
 '2020-07-02',
 '2021-01-26',
 '2021-04-16',
 '2021-08-06',
 '2021-08-22',
 '2021-09-07',
 '2021-09-23',
 '2021-10-25']

from datetime import date

list_set = []
for i in range(len(bad_dates)):   
    datetime_object = date.fromisoformat(bad_dates[i])
    start = datetime_object + timedelta(days=1)
    end = datetime_object - timedelta(days=1)
    
    list_set.append((str(start), str(end)))

for i in range(len(list_set)):
    collection = collection.filter(ee.Filter.date(list_set[i][0], list_set[i][1]).Not())

# %%
collection = collection.select(bands)
collection_list = collection.toList(collection.size())

collection_size = collection_list.size().getInfo()
dates = geemap.image_dates(collection, date_format='YYYY-MM-dd').getInfo()

# %%
print(collection_list.size().getInfo())
# Out:
# 4

# %%
for i, date in enumerate(dates[:]):
    
    if date in bad_dates:
        continue
        
    image = ee.Image(collection_list.get(i))


    new_image = image.select(bands)
# lower scale = higher resolution
#     path = os.path.join('port_la', 'port_la_img_{}.tif'.format(date))
    geemap.ee_export_image(new_image, filename = "port_la/port_la_img_2_{}.tif".format(date), scale = 30, region = region, file_per_band = False)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c05997afc8b0615161a89042e5c1c516-68904820b7a40dee95e1f86118b27aca:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_img_2_2022-01-14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/88b0db8c54fc9256d08de68ff2d0ddb2-8a164f36d34a86319dfdc2ae0cbd8f47:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_img_2_2022-01-30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5c9baa1a692904a8824222e0749217b1-a99a30f67c811343de0003dcbb4653ed:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_img_2_2022-01-14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1ef9248e40da640ea427d9b510711ef0-57f6dbf2cb07bf8f424d4eca4e17a36d:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_img_2_2022-01-30.tif

# %%
# get smaller areas, with maximized scale and then tile together to get best image

# %% [markdown]
# ## use sar image

# %%
# bounding box
bbox = [(-118.32027994564326,33.64246038322455),
(-118.07789408138545,33.64246038322455),
(-118.07789408138545,33.78867573774964),
(-118.32027994564326,33.78867573774964),
(-118.32027994564326,33.64246038322455)]

# %%
bands = ['B1','B2','B3','B4', 'TCI_R', 'TCI_G', 'TCI_B']

# %%
start_date = datetime(2022,1,1)

end_date = datetime(2022,2,1)

region = ee.Geometry.Polygon(bbox)

collection = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED").filterDate(start_date,end_date).filterBounds(region)

cloud_tol=100
# collection= collection.map(algorithm=cloudscore).filter(ee.Filter.lt('cloud', cloud_tol))

# %%
bad_dates = ['2013-04-05',
'2013-06-13',
 '2013-06-29',
 '2013-07-31',
 '2013-09-17',
 '2013-10-19',
 '2013-12-06',
 '2014-01-07',
 '2014-02-08',
 '2014-03-12',
 '2014-05-31',
 '2014-06-16',
 '2014-08-03',
 '2014-11-07',
 '2014-12-09',
 '2015-01-26',
 '2015-06-19',
 '2015-07-21',
 '2015-09-23',
 '2016-03-17',
 '2016-04-02',
 '2016-07-07',
 '2016-07-23',
 '2016-08-08',
 '2016-09-09',
 '2016-09-25',
 '2017-02-16',
 '2017-03-20',
 '2017-06-24',
 '2017-08-11',
 '2017-09-12',
 '2017-10-14',
 '2018-01-18',
 '2018-02-19',
 '2018-05-10',
 '2018-07-29',
 '2018-09-15',
 '2018-10-17',
 '2018-12-20',
 '2019-02-22',
 '2019-04-11',
 '2019-07-16',
 '2019-10-20',
 '2020-02-09',
 '2020-05-15',
 '2020-07-02',
 '2021-01-26',
 '2021-04-16',
 '2021-08-06',
 '2021-08-22',
 '2021-09-07',
 '2021-09-23',
 '2021-10-25']

from datetime import date

list_set = []
for i in range(len(bad_dates)):   
    datetime_object = date.fromisoformat(bad_dates[i])
    start = datetime_object + timedelta(days=1)
    end = datetime_object - timedelta(days=1)
    
    list_set.append((str(start), str(end)))

for i in range(len(list_set)):
    collection = collection.filter(ee.Filter.date(list_set[i][0], list_set[i][1]).Not())

# %%
print(geemap.image_dates(collection,date_format='YYY-MM-dd')).getInfo()
# Out:
# ee.List({
#   "functionInvocationValue": {
#     "functionName": "List.map",
#     "arguments": {
#       "baseAlgorithm": {
#         "functionDefinitionValue": {
#           "argumentNames": [
#             "_MAPPING_VAR_0_0"
#           ],
#           "body": {
#             "functionInvocationValue": {
#               "functionName": "Date.format",
#               "arguments": {
#                 "date": {
#                   "functionInvocationValue": {
#                     "functionName": "Date",
#                     "arguments": {
#                       "value": {
#                         "argumentReference": "_MAPPING_VAR_0_0"
#                       }
#                     }
#                   }
#                 },
#                 "format": {
#                   "constantValue": "YYY-MM-dd"
#                 }
#               }
#             }
#           }
#         }
#       },
#       "list": {
#         "functionInvocationValue": {
#           "functionName": "AggregateFeatureCollection.array",
#           "arguments": {
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.filter",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.filter",
#                       "arguments": {
#                         "collection": {
#                           "functionInvocationValue": {
#                             "functionName": "Collection.filter",
#                             "arguments": {
#                               "collection": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Collection.filter",
#                                   "arguments": {
#                                     "collection": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Collection.filter",
#                                         "arguments": {
#                                           "collection": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Collection.filter",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "Collection.filter",
#                                                     "arguments": {
#                                                       "collection": {
#                                                         "functionInvocationValue": {
#                                                           "functionName": "Collection.filter",
#                                                           "arguments": {
#                                                             "collection": {
#                                                               "functionInvocationValue": {
#                                                                 "functionName": "Collection.filter",
#                                                                 "arguments": {
#                                                                   "collection": {
#                                                                     "functionInvocationValue": {
#                                                                       "functionName": "Collection.filter",
#                                                                       "arguments": {
#                                                                         "collection": {
#                                                                           "functionInvocationValue": {
#                                                                             "functionName": "Collection.filter",
#                                                                             "arguments": {
#                                                                               "collection": {
#                                                                                 "functionInvocationValue": {
#                                                                                   "functionName": "Collection.filter",
#                                                                                   "arguments": {
#                                                                                     "collection": {
#                                                                                       "functionInvocationValue": {
#                                                                                         "functionName": "Collection.filter",
#                                                                                         "arguments": {
#                                                                                           "collection": {
#                                                                                             "functionInvocationValue": {
#                                                                                               "functionName": "Collection.filter",
#                                                                                               "arguments": {
#                                                                                                 "collection": {
#                                                                                                   "functionInvocationValue": {
#                                                                                                     "functionName": "Collection.filter",
#                                                                                                     "arguments": {
#                                                                                                       "collection": {
#                                                                                                         "functionInvocationValue": {
#                                                                                                           "functionName": "Collection.filter",
#                                                                                                           "arguments": {
#                                                                                                             "collection": {
#                                                                                                               "functionInvocationValue": {
#                                                                                                                 "functionName": "Collection.filter",
#                                                                                                                 "arguments": {
#                                                                                                                   "collection": {
#                                                                                                                     "functionInvocationValue": {
#                                                                                                                       "functionName": "Collection.filter",
#                                                                                                                       "arguments": {
#                                                                                                                         "collection": {
#                                                                                                                           "functionInvocationValue": {
#                                                                                                                             "functionName": "Collection.filter",
#                                                                                                                             "arguments": {
#                                                                                                                               "collection": {
#                                                                                                                                 "functionInvocationValue": {
#                                                                                                                                   "functionName": "Collection.filter",
#                                                                                                                                   "arguments": {
#                                                                                                                                     "collection": {
#                                                                                                                                       "functionInvocationValue": {
#                                                                                                                                         "functionName": "Collection.filter",
#                                                                                                                                         "arguments": {
#                                                                                                                                           "collection": {
#                                                                                                                                             "functionInvocationValue": {
#                                                                                                                                               "functionName": "Collection.filter",
#                                                                                                                                               "arguments": {
#                                                                                                                                                 "collection": {
#                                                                                                                                                   "functionInvocationValue": {
#                                                                                                                                                     "functionName": "Collection.filter",
#                                                                                                                                                     "arguments": {
#                                                                                                                                                       "collection": {
#                                                                                                                                                         "functionInvocationValue": {
#                                                                                                                                                           "functionName": "Collection.filter",
#                                                                                                                                                           "arguments": {
#                                                                                                                                                             "collection": {
#                                                                                                                                                               "functionInvocationValue": {
#                                                                                                                                                                 "functionName": "Collection.filter",
#                                                                                                                                                                 "arguments": {
#                                                                                                                                                                   "collection": {
#                                                                                                                                                                     "functionInvocationValue": {
#                                                                                                                                                                       "functionName": "Collection.filter",
#                                                                                                                                                                       "arguments": {
#                                                                                                                                                                         "collection": {
#                                                                                                                                                                           "functionInvocationValue": {
#                                                                                                                                                                             "functionName": "Collection.filter",
#                                                                                                                                                                             "arguments": {
#                                                                                                                                                                               "collection": {
#                                                                                                                                                                                 "functionInvocationValue": {
#                                                                                                                                                                                   "functionName": "Collection.filter",
#                                                                                                                                                                                   "arguments": {
#                                                                                                                                                                                     "collection": {
#                                                                                                                                                                                       "functionInvocationValue": {
#                                                                                                                                                                                         "functionName": "Collection.filter",
#                                                                                                                                                                                         "arguments": {
#                                                                                                                                                                                           "collection": {
#                                                                                                                                                                                             "functionInvocationValue": {
#                                                                                                                                                                                               "functionName": "Collection.filter",
#                                                                                                                                                                                               "arguments": {
#                                                                                                                                                                                                 "collection": {
#                                                                                                                                                                                                   "functionInvocationValue": {
#                                                                                                                                                                                                     "functionName": "Collection.filter",
#                                                                                                                                                                                                     "arguments": {
#                                                                                                                                                                                                       "collection": {
#                                                                                                                                                                                                         "functionInvocationValue": {
#                                                                                                                                                                                                           "functionName": "Collection.filter",
#                                                                                                                                                                                                           "arguments": {
#                                                                                                                                                                                                             "collection": {
#                                                                                                                                                                                                               "functionInvocationValue": {
#                                                                                                                                                                                                                 "functionName": "Collection.filter",
#                                                                                                                                                                                                                 "arguments": {
#                                                                                                                                                                                                                   "collection": {
#                                                                                                                                                                                                                     "functionInvocationValue": {
#                                                                                                                                                                                                                       "functionName": "Collection.filter",
#                                                                                                                                                                                                                       "arguments": {
#                                                                                                                                                                                                                         "collection": {
#                                                                                                                                                                                                                           "functionInvocationValue": {
#                                                                                                                                                                                                                             "functionName": "Collection.filter",
#                                                                                                                                                                                                                             "arguments": {
#                                                                                                                                                                                                                               "collection": {
#                                                                                                                                                                                                                                 "functionInvocationValue": {
#                                                                                                                                                                                                                                   "functionName": "Collection.filter",
#                                                                                                                                                                                                                                   "arguments": {
#                                                                                                                                                                                                                                     "collection": {
#                                                                                                                                                                                                                                       "functionInvocationValue": {
#                                                                                                                                                                                                                                         "functionName": "Collection.filter",
#                                                                                                                                                                                                                                         "arguments": {
#                                                                                                                                                                                                                                           "collection": {
#                                                                                                                                                                                                                                             "functionInvocationValue": {
#                                                                                                                                                                                                                                               "functionName": "Collection.filter",
#                                                                                                                                                                                                                                               "arguments": {
#                                                                                                                                                                                                                                                 "collection": {
#                                                                                                                                                                                                                                                   "functionInvocationValue": {
#                                                                                                                                                                                                                                                     "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                     "arguments": {
#                                                                                                                                                                                                                                                       "collection": {
#                                                                                                                                                                                                                                                         "functionInvocationValue": {
#                                                                                                                                                                                                                                                           "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                           "arguments": {
#                                                                                                                                                                                                                                                             "collection": {
#                                                                                                                                                                                                                                                               "functionInvocationValue": {
#                                                                                                                                                                                                                                                                 "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                 "arguments": {
#                                                                                                                                                                                                                                                                   "collection": {
#                                                                                                                                                                                                                                                                     "functionInvocationValue": {
#                                                                                                                                                                                                                                                                       "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                       "arguments": {
#                                                                                                                                                                                                                                                                         "collection": {
#                                                                                                                                                                                                                                                                           "functionInvocationValue": {
#                                                                                                                                                                                                                                                                             "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                             "arguments": {
#                                                                                                                                                                                                                                                                               "collection": {
#                                                                                                                                                                                                                                                                                 "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                   "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                   "arguments": {
#                                                                                                                                                                                                                                                                                     "collection": {
#                                                                                                                                                                                                                                                                                       "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                         "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                         "arguments": {
#                                                                                                                                                                                                                                                                                           "collection": {
#                                                                                                                                                                                                                                                                                             "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                               "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                               "arguments": {
#                                                                                                                                                                                                                                                                                                 "collection": {
#                                                                                                                                                                                                                                                                                                   "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                     "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                     "arguments": {
#                                                                                                                                                                                                                                                                                                       "collection": {
#                                                                                                                                                                                                                                                                                                         "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                           "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                           "arguments": {
#                                                                                                                                                                                                                                                                                                             "collection": {
#                                                                                                                                                                                                                                                                                                               "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                 "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                 "arguments": {
#                                                                                                                                                                                                                                                                                                                   "collection": {
#                                                                                                                                                                                                                                                                                                                     "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                       "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                       "arguments": {
#                                                                                                                                                                                                                                                                                                                         "collection": {
#                                                                                                                                                                                                                                                                                                                           "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                             "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                             "arguments": {
#                                                                                                                                                                                                                                                                                                                               "collection": {
#                                                                                                                                                                                                                                                                                                                                 "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                                   "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                                   "arguments": {
#                                                                                                                                                                                                                                                                                                                                     "collection": {
#                                                                                                                                                                                                                                                                                                                                       "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                                         "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                                         "arguments": {
#                                                                                                                                                                                                                                                                                                                                           "collection": {
#                                                                                                                                                                                                                                                                                                                                             "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                                               "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                                               "arguments": {
#                                                                                                                                                                                                                                                                                                                                                 "collection": {
#                                                                                                                                                                                                                                                                                                                                                   "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                                                     "functionName": "Collection.filter",
#                                                                                                                                                                                                                                                                                                                                                     "arguments": {
#                                                                                                                                                                                                                                                                                                                                                       "collection": {
#                                                                                                                                                                                                                                                                                                                                                         "functionInvocationValue": {
#                                                                                                                                                                                                                                                                                                                                                           "functionName": "ImageCollection.load",
#                                                                                                                                                                                                                                                                                                                                                           "arguments": {
#                                                                                                                                                                                                                                                                                                                                                             "id": {
#                                                                                                                                                                                                                                                                                                                                                               "constantValue": "COPERNICUS/S2_SR_HARMONIZED"
#                                                                                                                                                                                                                                                                                                                                                             }
# ...
#                                                                             "functionName": "DateRange",
#                                                                             "arguments": {
#                                                                               "end": {
#                                                                                 "constantValue": "2020-07-01"
#                                                                               },
#                                                                               "start": {
#                                                                                 "constantValue": "2020-07-03"
#                                                                               }
#                                                                             }
#                                                                           }
#                                                                         },
#                                                                         "rightField": {
#                                                                           "constantValue": "system:time_start"
#                                                                         }
#                                                                       }
#                                                                     }
#                                                                   }
#                                                                 }
#                                                               }
#                                                             }
#                                                           }
#                                                         }
#                                                       },
#                                                       "filter": {
#                                                         "functionInvocationValue": {
#                                                           "functionName": "Filter.not",
#                                                           "arguments": {
#                                                             "filter": {
#                                                               "functionInvocationValue": {
#                                                                 "functionName": "Filter.dateRangeContains",
#                                                                 "arguments": {
#                                                                   "leftValue": {
#                                                                     "functionInvocationValue": {
#                                                                       "functionName": "DateRange",
#                                                                       "arguments": {
#                                                                         "end": {
#                                                                           "constantValue": "2021-01-25"
#                                                                         },
#                                                                         "start": {
#                                                                           "constantValue": "2021-01-27"
#                                                                         }
#                                                                       }
#                                                                     }
#                                                                   },
#                                                                   "rightField": {
#                                                                     "constantValue": "system:time_start"
#                                                                   }
#                                                                 }
#                                                               }
#                                                             }
#                                                           }
#                                                         }
#                                                       }
#                                                     }
#                                                   }
#                                                 },
#                                                 "filter": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "Filter.not",
#                                                     "arguments": {
#                                                       "filter": {
#                                                         "functionInvocationValue": {
#                                                           "functionName": "Filter.dateRangeContains",
#                                                           "arguments": {
#                                                             "leftValue": {
#                                                               "functionInvocationValue": {
#                                                                 "functionName": "DateRange",
#                                                                 "arguments": {
#                                                                   "end": {
#                                                                     "constantValue": "2021-04-15"
#                                                                   },
#                                                                   "start": {
#                                                                     "constantValue": "2021-04-17"
#                                                                   }
#                                                                 }
#                                                               }
#                                                             },
#                                                             "rightField": {
#                                                               "constantValue": "system:time_start"
#                                                             }
#                                                           }
#                                                         }
#                                                       }
#                                                     }
#                                                   }
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.not",
#                                               "arguments": {
#                                                 "filter": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "Filter.dateRangeContains",
#                                                     "arguments": {
#                                                       "leftValue": {
#                                                         "functionInvocationValue": {
#                                                           "functionName": "DateRange",
#                                                           "arguments": {
#                                                             "end": {
#                                                               "constantValue": "2021-08-05"
#                                                             },
#                                                             "start": {
#                                                               "constantValue": "2021-08-07"
#                                                             }
#                                                           }
#                                                         }
#                                                       },
#                                                       "rightField": {
#                                                         "constantValue": "system:time_start"
#                                                       }
#                                                     }
#                                                   }
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     },
#                                     "filter": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Filter.not",
#                                         "arguments": {
#                                           "filter": {
#                                             "functionInvocationValue": {
#                                               "functionName": "Filter.dateRangeContains",
#                                               "arguments": {
#                                                 "leftValue": {
#                                                   "functionInvocationValue": {
#                                                     "functionName": "DateRange",
#                                                     "arguments": {
#                                                       "end": {
#                                                         "constantValue": "2021-08-21"
#                                                       },
#                                                       "start": {
#                                                         "constantValue": "2021-08-23"
#                                                       }
#                                                     }
#                                                   }
#                                                 },
#                                                 "rightField": {
#                                                   "constantValue": "system:time_start"
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               },
#                               "filter": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Filter.not",
#                                   "arguments": {
#                                     "filter": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Filter.dateRangeContains",
#                                         "arguments": {
#                                           "leftValue": {
#                                             "functionInvocationValue": {
#                                               "functionName": "DateRange",
#                                               "arguments": {
#                                                 "end": {
#                                                   "constantValue": "2021-09-06"
#                                                 },
#                                                 "start": {
#                                                   "constantValue": "2021-09-08"
#                                                 }
#                                               }
#                                             }
#                                           },
#                                           "rightField": {
#                                             "constantValue": "system:time_start"
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         },
#                         "filter": {
#                           "functionInvocationValue": {
#                             "functionName": "Filter.not",
#                             "arguments": {
#                               "filter": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Filter.dateRangeContains",
#                                   "arguments": {
#                                     "leftValue": {
#                                       "functionInvocationValue": {
#                                         "functionName": "DateRange",
#                                         "arguments": {
#                                           "end": {
#                                             "constantValue": "2021-09-22"
#                                           },
#                                           "start": {
#                                             "constantValue": "2021-09-24"
#                                           }
#                                         }
#                                       }
#                                     },
#                                     "rightField": {
#                                       "constantValue": "system:time_start"
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "filter": {
#                     "functionInvocationValue": {
#                       "functionName": "Filter.not",
#                       "arguments": {
#                         "filter": {
#                           "functionInvocationValue": {
#                             "functionName": "Filter.dateRangeContains",
#                             "arguments": {
#                               "leftValue": {
#                                 "functionInvocationValue": {
#                                   "functionName": "DateRange",
#                                   "arguments": {
#                                     "end": {
#                                       "constantValue": "2021-10-24"
#                                     },
#                                     "start": {
#                                       "constantValue": "2021-10-26"
#                                     }
#                                   }
#                                 }
#                               },
#                               "rightField": {
#                                 "constantValue": "system:time_start"
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "property": {
#               "constantValue": "system:time_start"
#             }
#           }
#         }
#       }
#     }
#   }
# })
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1744/556447629.py in <module>
# ----> 1 print(geemap.image_dates(collection,date_format='YYY-MM-dd')).getInfo()
#
# AttributeError: 'NoneType' object has no attribute 'getInfo'

# %%
collection = collection.select(bands)
collection_list = collection.toList(collection.size())

# collection_size = collection_list.size().getInfo()
dates = geemap.image_dates(collection, date_format='YYYY-MM-dd').getInfo()

# %%
for i, date in enumerate(dates[:]):
    
    if date in bad_dates:
        continue
        
    image = ee.Image(collection_list.get(i))


    new_image = image.select(bands)
# lower scale = higher resolution
#     path = os.path.join('port_la', 'port_la_img_{}.tif'.format(date))
    geemap.ee_export_image(new_image, filename = "port_la/port_la_sar_{}.tif".format(date), scale = 30, region = region, file_per_band = False)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e9a390ad41c4947a1b0eb5eb17c8214b-1a5f657c6c7ea7aa6eb30bc9ee9a4ae1:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9817d4ca281c42941b46b781630150e5-8e50884f609cef52d57bb730fee98ecd:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/375776dfc68cec0835244665f5e5f27d-bc839b1d234626e4c7357b8c41e31668:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c029ca78cb12498303bdd0dec601aa40-9ffb9e1a56cc263629a3aa466b1c0445:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/602a6a24c1274cfc380b9c0ffe937bfc-e0ad327dcb411e181a922e65f8226d26:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c2a504fc7e87c70abfdf46a26901f7ec-1f3eaf784e49de53df0c2f3eebf24885:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4ff8d582c0a6ff06c0af850c239e2890-82421935001f97ae21695bc90e65db91:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/250a0cdff9c2ada0e77985cf0147a091-14e12637a0bee1b0115567803f520cee:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/04e8e53841e2fc226db9144309f5d508-d752cd49c7bb215dfdcd01a171cde095:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/039534bb5e48b0f358ac62f46399e942-d329b86038c6007de844e2ed5f291021:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/960e8235be8ed62aebbbd1971eee2446-8280a060fd77df2c3cb38396a068a8d2:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/10fa0928ea8e014b470d50929ecee1fb-ba41222809dc682022c483b9bdf8c11d:getPixels
# Please wait ...
# Data downloaded to C:\Users\seann\dsc_180a\sat_img\sat_img_rough\port_la\port_la_sar_2022-01-28.tif
